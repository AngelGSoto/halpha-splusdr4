# %%
import pandas as pd
import os
import shutil

# %%
df=pd.read_table('../Ha-emitters/SDSS-spectra/spectra-information_sdss-unique-plus-photometry.csv', sep=',')

# %%
df
# Out:
#                 Field                             ID_1        RA_1     DEC_1  \
# 0     b'SPLUS-s02s07'   b'iDR4_3_SPLUS-s02s07_0040775'  333.176070 -1.066343
# 1     b'SPLUS-s02s10'   b'iDR4_3_SPLUS-s02s10_0028491'  336.306450 -1.255425
# 2     b'SPLUS-s02s12'   b'iDR4_3_SPLUS-s02s12_0021758'  338.911167 -1.031257
# 3    b'STRIPE82-0018'  b'iDR4_3_STRIPE82-0018_0010309'   11.156943  0.243199
# 4    b'STRIPE82-0029'  b'iDR4_3_STRIPE82-0029_0043702'   20.329553 -0.330578
# ..                ...                              ...         ...       ...
# 133  b'STRIPE82-0142'  b'iDR4_3_STRIPE82-0142_0014029'  339.139727  0.448016
# 134  b'STRIPE82-0145'  b'iDR4_3_STRIPE82-0145_0038826'  341.416423 -0.405451
# 135  b'STRIPE82-0147'  b'iDR4_3_STRIPE82-0147_0003349'  343.495206 -1.289140
# 136  b'STRIPE82-0151'  b'iDR4_3_STRIPE82-0151_0033785'  346.434130 -0.425545
# 137  b'STRIPE82-0158'  b'iDR4_3_STRIPE82-0158_0009177'  350.254869  0.323001
#
# ...

# %%
mask_r = df["r_PStotal"]>=19 # en SDSS nio hay strellas saturados
df_cut = df[mask_r]
df_cut
# Out:
#                 Field                             ID_1        RA_1     DEC_1  \
# 89    b'SPLUS-n01s26'   b'iDR4_3_SPLUS-n01s26_0014002'  184.926988 -0.305940
# 92    b'SPLUS-n02n23'   b'iDR4_3_SPLUS-n02n23_0017570'  180.159526  1.212904
# 96   b'STRIPE82-0007'  b'iDR4_3_STRIPE82-0007_0017895'    4.380263 -0.816439
# 100  b'STRIPE82-0025'  b'iDR4_3_STRIPE82-0025_0026093'   17.358161 -0.627516
# 102  b'STRIPE82-0029'  b'iDR4_3_STRIPE82-0029_0055255'   19.602082 -0.251813
# 105  b'STRIPE82-0042'  b'iDR4_3_STRIPE82-0042_0015943'   28.538615  0.445912
# 108  b'STRIPE82-0051'  b'iDR4_3_STRIPE82-0051_0001065'   35.713130 -1.346684
# 109  b'STRIPE82-0055'  b'iDR4_3_STRIPE82-0055_0003875'   38.127636 -1.281808
# 112  b'STRIPE82-0059'  b'iDR4_3_STRIPE82-0059_0006249'   41.717321 -1.211895
# 115  b'STRIPE82-0068'  b'iDR4_3_STRIPE82-0068_0003808'   46.989796  0.120015
# 118  b'STRIPE82-0101'  b'iDR4_3_STRIPE82-0101_0062358'  310.645648 -0.528915
# ...

# %%
# Use .str.replace() to replace ".fits" with "-b.pdf"
df_cut['FileName'] = df_cut['FileName'].str.replace(".fits", "-b.pdf")
len(df_cut['FileName'])
# Out:
# /tmp/ipykernel_163310/940719631.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cut['FileName'] = df_cut['FileName'].str.replace(".fits", "-b.pdf")
# 19

# %%
# Directory paths
source_dir = '../Ha-emitters/SDSS-spectra/'
destination_dir = '../Ha-emitters/SDSS-nosaturated/'

# %%
# Iterate over each row in the DataFrame
for index, row in df_cut.iterrows():
    filename = row['FileName']
    source_file = os.path.join(source_dir, filename)
    destination_file = os.path.join(destination_dir, filename)
    # Check if the file exists in the source directory
    if os.path.isfile(source_file):
        # Copy the file to the destination directory
        shutil.copy(source_file, destination_file)
        print(f"Copied {source_file} to {destination_file}")
    else:
        print(f"File {filename} not found in {source_dir}")

print("Copy operation completed.")
# Out:
# Copied ../Ha-emitters/Lamost-spectra/spec-56654-HD120800N003716B01_sp09-210-b.pdf to ../Ha-emitters/Lamost-nosaturated/spec-56654-HD120800N003716B01_sp09-210-b.pdf
# Copied ../Ha-emitters/Lamost-spectra/spec-59318-HD123204S014620B02_sp10-001-b.pdf to ../Ha-emitters/Lamost-nosaturated/spec-59318-HD123204S014620B02_sp10-001-b.pdf
# Copied ../Ha-emitters/Lamost-spectra/spec-56971-EG222332S021805B01_sp09-123-b.pdf to ../Ha-emitters/Lamost-nosaturated/spec-56971-EG222332S021805B01_sp09-123-b.pdf
# Copied ../Ha-emitters/Lamost-spectra/spec-56213-EG000023N024031B01_sp02-059-b.pdf to ../Ha-emitters/Lamost-nosaturated/spec-56213-EG000023N024031B01_sp02-059-b.pdf
# Copied ../Ha-emitters/Lamost-spectra/spec-56232-EG011815N023302V01_sp02-127-b.pdf to ../Ha-emitters/Lamost-nosaturated/spec-56232-EG011815N023302V01_sp02-127-b.pdf
# Copied ../Ha-emitters/Lamost-spectra/spec-56604-EG012606S021203F04_sp16-007-b.pdf to ../Ha-emitters/Lamost-nosaturated/spec-56604-EG012606S021203F04_sp16-007-b.pdf
# ...
